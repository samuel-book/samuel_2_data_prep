# %% [markdown]
# # Creating a control non-thrombolysed patient data set with similar characteristics to thrombolysed patients
#
# The aim of this notebook is to create 'control' non-thrombolysed patient data that has similar overall patient characteristics to the thrombolysed group of patients, emulating a clinical trial for thrombolysis.
#
# Non-thrombolysed patients will be selected based using a nearest-neighbour method based on key patient characteristics.

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler

# Turn off warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Import data

# %%
all_data = pd.read_csv('../output/reformatted_data.csv')

# Limit to years 2017 to 2019
mask = (all_data['year'] >= 2017) & (all_data['year'] <= 2019)
data = all_data[mask]

# Limit to infarction stroke
mask = (data['infarction'] == 1)
data = data[mask]

# Limit to arrivals by ambulace
mask = (data['arrive_by_ambulance'] == 1)
data = data[mask]

# Remove patiens who have received thrombectomy
mask = (data['thrombectomy'] == 0)

# %% [markdown]
# Limit to patient clinical characteristics (not arrival timings).

# %%
required_cols = [
    'age',
    'male',
    'infarction',
    'thrombolysis',
    'congestive_heart_failure',
    'hypertension',
    'atrial_fibrillation',
    'diabetes',
    'prior_stroke_tia',
    'afib_anticoagulant',
    'prior_disability',
    'stroke_severity',
    'nihss_complete',
    'nihss_arrival_loc',
    'nihss_arrival_loc_questions',
    'nihss_arrival_loc_commands',
    'nihss_arrival_best_gaze',
    'nihss_arrival_visual',
    'nihss_arrival_facial_palsy',
    'nihss_arrival_motor_arm_left',
    'nihss_arrival_motor_arm_right',
    'nihss_arrival_motor_leg_left',
    'nihss_arrival_motor_leg_right',
    'nihss_arrival_limb_ataxia',
    'nihss_arrival_sensory',
    'nihss_arrival_best_language',
    'nihss_arrival_dysarthria',
    'nihss_arrival_extinction_inattention',
    'discharge_destination',
    'death',
    'discharge_disability',
    'disability_6_month'
    ]

# %%
data = data[required_cols]

# Keep only complete cases
data = data.dropna()
data.shape
# Out:
# (35860, 32)

# %% [markdown]
# ## Split data by use of thrombolysis

# %%
# Split the data into two groups
data_thrombolysis = data[data['thrombolysis'] == 1]
data_no_thrombolysis = data[data['thrombolysis'] == 0]

# Shuffle the data
data_thrombolysis = data_thrombolysis.sample(frac=1, random_state=42)
data_no_thrombolysis = data_no_thrombolysis.sample(frac=1, random_state=42)

# %% [markdown]
# ## Select the columns to be used for nearest neighbour

# %%
nn_cols = [
    'prior_disability',
    'stroke_severity',
    'age',
    'male',
    'congestive_heart_failure',
    'hypertension',
    'atrial_fibrillation',
    'diabetes',
    'prior_stroke_tia',
    'afib_anticoagulant'
]

# %% [markdown]
# ## Standardise the data

# %%
# Concatenate the data
concatenated_data = pd.concat([data_thrombolysis, data_no_thrombolysis])
# Scale the data based on concatenated data
scaler = StandardScaler()
scaler.fit(concatenated_data[nn_cols])
data_thrombolysis_standardised = scaler.transform(data_thrombolysis[nn_cols])
data_no_thrombolysis_standardised = scaler.transform(data_no_thrombolysis[nn_cols])

# %% [markdown]
# ## Find nearest neighbours to each thrombolysed patients
#
# We will find the three nearest neighbours

# %%
# Set up nearest neighbour engine
nn = NearestNeighbors(n_neighbors=3, algorithm='auto').fit(
    data_no_thrombolysis_standardised)

# Loop through the data_no_thrombolysis_standardised data and find the nearest neighbour in data_thrombolysis_standardised
distances, indices = nn.kneighbors(data_thrombolysis_standardised)

# Get the indices of the nearest neighbours
indices = pd.Series(indices.reshape(len(indices.flatten())))

# Drop duplicate rows
indices = indices.drop_duplicates()

# %%
nearest_neighbour_size = len(indices)
sample_size = data_thrombolysis.shape[0]

print (f'Nearest neighbours found: {nearest_neighbour_size}')
print (f'Required sample size: {sample_size}')

# Sample the data
replacement = True if nearest_neighbour_size < sample_size else False
indicies = indices.sample(sample_size, replace=replacement, random_state=42).values
sampled_no_thrombolysis = data_no_thrombolysis.iloc[indicies]
# Out:
# Nearest neighbours found: 7201
# Required sample size: 5822

# %% [markdown]
# ## Show data statistics
#
# ### Summary statistics

# %%
results = pd.DataFrame()
results['all_data'] = data.mean()
results['all no thrombolysis'] = data_no_thrombolysis.mean()
results['sampled no thrombolysis'] = sampled_no_thrombolysis.mean()
results['thrombolysis'] = data_thrombolysis.mean()
results
# Out:
#                                        all_data  all no thrombolysis  \
# age                                   75.070970            75.590585
# male                                   0.525432             0.517445
# infarction                             1.000000             1.000000
# thrombolysis                           0.162354             0.000000
# congestive_heart_failure               0.051645             0.053665
# hypertension                           0.557306             0.565584
# atrial_fibrillation                    0.177635             0.191457
# diabetes                               0.216899             0.225980
# prior_stroke_tia                       0.264752             0.276583
# afib_anticoagulant                     0.120245             0.138225
# prior_disability                       1.012688             1.089353
# stroke_severity                        6.165728             5.393402
# nihss_complete                         0.966481             0.964745
# nihss_arrival_loc                      0.099972             0.092916
# nihss_arrival_loc_questions            0.439375             0.388142
# nihss_arrival_loc_commands             0.182571             0.156468
# nihss_arrival_best_gaze                0.156079             0.117152
# nihss_arrival_visual                   0.300641             0.252247
# nihss_arrival_facial_palsy             0.646068             0.552800
# nihss_arrival_motor_arm_left           0.542722             0.474732
# nihss_arrival_motor_arm_right          0.505270             0.428424
# nihss_arrival_motor_leg_left           0.550139             0.486983
# nihss_arrival_motor_leg_right          0.527942             0.459884
# nihss_arrival_limb_ataxia              0.267680             0.259371
# nihss_arrival_sensory                  0.343558             0.293462
# nihss_arrival_best_language            0.536001             0.451894
# nihss_arrival_dysarthria               0.551394             0.486950
# nihss_arrival_extinction_inattention   0.265756             0.206006
# death                                  0.000000             0.000000
# discharge_disability                   2.204378             2.234803
# disability_6_month                     2.359175             2.420301
#
#                                       sampled no thrombolysis  thrombolysis
# age                                                 74.215046     72.390072
# male                                                 0.514600      0.566644
# infarction                                           1.000000      1.000000
# thrombolysis                                         0.000000      1.000000
# congestive_heart_failure                             0.065270      0.041223
# hypertension                                         0.539677      0.514600
# atrial_fibrillation                                  0.156819      0.106321
# diabetes                                             0.233768      0.170045
# prior_stroke_tia                                     0.283236      0.203710
# afib_anticoagulant                                   0.057025      0.027482
# prior_disability                                     0.995362      0.617142
# stroke_severity                                      9.194950     10.150464
# nihss_complete                                       0.969426      0.975438
# nihss_arrival_loc                                    0.181209      0.136379
# nihss_arrival_loc_questions                          0.692546      0.703710
# nihss_arrival_loc_commands                           0.336311      0.317245
# nihss_arrival_best_gaze                              0.270526      0.356922
# nihss_arrival_visual                                 0.478358      0.550326
# nihss_arrival_facial_palsy                           0.891103      1.127276
# nihss_arrival_motor_arm_left                         0.841120      0.893507
# nihss_arrival_motor_arm_right                        0.798179      0.901752
# nihss_arrival_motor_leg_left                         0.869976      0.875988
# nihss_arrival_motor_leg_right                        0.821367      0.879079
# nihss_arrival_limb_ataxia                            0.342150      0.310546
# nihss_arrival_sensory                                0.535898      0.602027
# nihss_arrival_best_language                          0.791309      0.969942
# nihss_arrival_dysarthria                             0.774820      0.883889
# nihss_arrival_extinction_inattention                 0.457918      0.574030
# death                                                0.000000      0.000000
# discharge_disability                                 2.584851      2.047406
# disability_6_month                                   2.774648      2.043799

# %% [markdown]
# ### Full statisics

# %%
data.describe().T
# Out:
#                                         count       mean        std   min  \
# age                                   35860.0  75.070970  12.597642  37.5
# male                                  35860.0   0.525432   0.499360   0.0
# infarction                            35860.0   1.000000   0.000000   1.0
# thrombolysis                          35860.0   0.162354   0.368780   0.0
# congestive_heart_failure              35860.0   0.051645   0.221313   0.0
# hypertension                          35860.0   0.557306   0.496712   0.0
# atrial_fibrillation                   35860.0   0.177635   0.382211   0.0
# diabetes                              35860.0   0.216899   0.412139   0.0
# prior_stroke_tia                      35860.0   0.264752   0.441207   0.0
# afib_anticoagulant                    35860.0   0.120245   0.325253   0.0
# prior_disability                      35860.0   1.012688   1.335589   0.0
# stroke_severity                       35860.0   6.165728   5.997164   0.0
# nihss_complete                        35860.0   0.966481   0.179991   0.0
# nihss_arrival_loc                     35860.0   0.099972   0.375814   0.0
# nihss_arrival_loc_questions           35860.0   0.439375   0.805410  -1.0
# nihss_arrival_loc_commands            35860.0   0.182571   0.561003  -1.0
# nihss_arrival_best_gaze               35860.0   0.156079   0.502023  -1.0
# nihss_arrival_visual                  35860.0   0.300641   0.717720  -1.0
# nihss_arrival_facial_palsy            35860.0   0.646068   0.812935  -1.0
# nihss_arrival_motor_arm_left          35860.0   0.542722   1.070451  -1.0
# nihss_arrival_motor_arm_right         35860.0   0.505270   1.064055  -1.0
# nihss_arrival_motor_leg_left          35860.0   0.550139   1.068486  -1.0
# nihss_arrival_motor_leg_right         35860.0   0.527942   1.083211  -1.0
# nihss_arrival_limb_ataxia             35860.0   0.267680   0.614201  -1.0
# nihss_arrival_sensory                 35860.0   0.343558   0.644635  -1.0
# nihss_arrival_best_language           35860.0   0.536001   0.916499  -1.0
# nihss_arrival_dysarthria              35860.0   0.551394   0.710270  -1.0
# nihss_arrival_extinction_inattention  35860.0   0.265756   0.630684  -1.0
# death                                 35860.0   0.000000   0.000000   0.0
# discharge_disability                  35860.0   2.204378   1.447127   0.0
# disability_6_month                    35860.0   2.359175   1.875974   0.0
#
#                                        25%   50%   75%   max
# age                                   67.5  77.5  82.5  92.5
# male                                   0.0   1.0   1.0   1.0
# infarction                             1.0   1.0   1.0   1.0
# thrombolysis                           0.0   0.0   0.0   1.0
# congestive_heart_failure               0.0   0.0   0.0   1.0
# hypertension                           0.0   1.0   1.0   1.0
# atrial_fibrillation                    0.0   0.0   0.0   1.0
# diabetes                               0.0   0.0   0.0   1.0
# prior_stroke_tia                       0.0   0.0   1.0   1.0
# afib_anticoagulant                     0.0   0.0   0.0   1.0
# prior_disability                       0.0   0.0   2.0   5.0
# stroke_severity                        2.0   4.0   8.0  42.0
# nihss_complete                         1.0   1.0   1.0   1.0
# nihss_arrival_loc                      0.0   0.0   0.0   3.0
# nihss_arrival_loc_questions            0.0   0.0   1.0   2.0
# nihss_arrival_loc_commands             0.0   0.0   0.0   2.0
# nihss_arrival_best_gaze                0.0   0.0   0.0   2.0
# nihss_arrival_visual                   0.0   0.0   0.0   3.0
# nihss_arrival_facial_palsy             0.0   0.0   1.0   3.0
# nihss_arrival_motor_arm_left           0.0   0.0   1.0   4.0
# nihss_arrival_motor_arm_right          0.0   0.0   1.0   4.0
# nihss_arrival_motor_leg_left           0.0   0.0   1.0   4.0
# nihss_arrival_motor_leg_right          0.0   0.0   1.0   4.0
# nihss_arrival_limb_ataxia              0.0   0.0   0.0   2.0
# nihss_arrival_sensory                  0.0   0.0   1.0   2.0
# nihss_arrival_best_language            0.0   0.0   1.0   3.0
# nihss_arrival_dysarthria               0.0   0.0   1.0   2.0
# nihss_arrival_extinction_inattention   0.0   0.0   0.0   2.0
# death                                  0.0   0.0   0.0   0.0
# discharge_disability                   1.0   2.0   3.0   5.0
# disability_6_month                     1.0   2.0   3.0   6.0

# %%
data_no_thrombolysis.describe().T
# Out:
#                                         count       mean        std   min  \
# age                                   30038.0  75.590585  12.483915  37.5
# male                                  30038.0   0.517445   0.499704   0.0
# infarction                            30038.0   1.000000   0.000000   1.0
# thrombolysis                          30038.0   0.000000   0.000000   0.0
# congestive_heart_failure              30038.0   0.053665   0.225360   0.0
# hypertension                          30038.0   0.565584   0.495688   0.0
# atrial_fibrillation                   30038.0   0.191457   0.393455   0.0
# diabetes                              30038.0   0.225980   0.418233   0.0
# prior_stroke_tia                      30038.0   0.276583   0.447316   0.0
# afib_anticoagulant                    30038.0   0.138225   0.345142   0.0
# prior_disability                      30038.0   1.089353   1.367662   0.0
# stroke_severity                       30038.0   5.393402   5.594712   0.0
# nihss_complete                        30038.0   0.964745   0.184428   0.0
# nihss_arrival_loc                     30038.0   0.092916   0.370881   0.0
# nihss_arrival_loc_questions           30038.0   0.388142   0.773768  -1.0
# nihss_arrival_loc_commands            30038.0   0.156468   0.535350  -1.0
# nihss_arrival_best_gaze               30038.0   0.117152   0.456692  -1.0
# nihss_arrival_visual                  30038.0   0.252247   0.675249  -1.0
# nihss_arrival_facial_palsy            30038.0   0.552800   0.764768  -1.0
# nihss_arrival_motor_arm_left          30038.0   0.474732   0.990825  -1.0
# nihss_arrival_motor_arm_right         30038.0   0.428424   0.970786  -1.0
# nihss_arrival_motor_leg_left          30038.0   0.486983   1.004806  -1.0
# nihss_arrival_motor_leg_right         30038.0   0.459884   1.010831  -1.0
# nihss_arrival_limb_ataxia             30038.0   0.259371   0.609494  -1.0
# nihss_arrival_sensory                 30038.0   0.293462   0.607905  -1.0
# nihss_arrival_best_language           30038.0   0.451894   0.854887  -1.0
# nihss_arrival_dysarthria              30038.0   0.486950   0.685832  -1.0
# nihss_arrival_extinction_inattention  30038.0   0.206006   0.576742  -1.0
# death                                 30038.0   0.000000   0.000000   0.0
# discharge_disability                  30038.0   2.234803   1.449451   0.0
# disability_6_month                    30038.0   2.420301   1.893357   0.0
#
#                                        25%   50%   75%   max
# age                                   67.5  77.5  87.5  92.5
# male                                   0.0   1.0   1.0   1.0
# infarction                             1.0   1.0   1.0   1.0
# thrombolysis                           0.0   0.0   0.0   0.0
# congestive_heart_failure               0.0   0.0   0.0   1.0
# hypertension                           0.0   1.0   1.0   1.0
# atrial_fibrillation                    0.0   0.0   0.0   1.0
# diabetes                               0.0   0.0   0.0   1.0
# prior_stroke_tia                       0.0   0.0   1.0   1.0
# afib_anticoagulant                     0.0   0.0   0.0   1.0
# prior_disability                       0.0   0.0   2.0   5.0
# stroke_severity                        2.0   4.0   7.0  42.0
# nihss_complete                         1.0   1.0   1.0   1.0
# nihss_arrival_loc                      0.0   0.0   0.0   3.0
# nihss_arrival_loc_questions            0.0   0.0   0.0   2.0
# nihss_arrival_loc_commands             0.0   0.0   0.0   2.0
# nihss_arrival_best_gaze                0.0   0.0   0.0   2.0
# nihss_arrival_visual                   0.0   0.0   0.0   3.0
# nihss_arrival_facial_palsy             0.0   0.0   1.0   3.0
# nihss_arrival_motor_arm_left           0.0   0.0   1.0   4.0
# nihss_arrival_motor_arm_right          0.0   0.0   0.0   4.0
# nihss_arrival_motor_leg_left           0.0   0.0   1.0   4.0
# nihss_arrival_motor_leg_right          0.0   0.0   0.0   4.0
# nihss_arrival_limb_ataxia              0.0   0.0   0.0   2.0
# nihss_arrival_sensory                  0.0   0.0   1.0   2.0
# nihss_arrival_best_language            0.0   0.0   1.0   3.0
# nihss_arrival_dysarthria               0.0   0.0   1.0   2.0
# nihss_arrival_extinction_inattention   0.0   0.0   0.0   2.0
# death                                  0.0   0.0   0.0   0.0
# discharge_disability                   1.0   2.0   3.0   5.0
# disability_6_month                     1.0   2.0   3.0   6.0

# %%
sampled_no_thrombolysis.describe().T
# Out:
#                                        count       mean        std   min  \
# age                                   5822.0  74.215046  13.138357  37.5
# male                                  5822.0   0.514600   0.499830   0.0
# infarction                            5822.0   1.000000   0.000000   1.0
# thrombolysis                          5822.0   0.000000   0.000000   0.0
# congestive_heart_failure              5822.0   0.065270   0.247022   0.0
# hypertension                          5822.0   0.539677   0.498466   0.0
# atrial_fibrillation                   5822.0   0.156819   0.363661   0.0
# diabetes                              5822.0   0.233768   0.423263   0.0
# prior_stroke_tia                      5822.0   0.283236   0.450609   0.0
# afib_anticoagulant                    5822.0   0.057025   0.231910   0.0
# prior_disability                      5822.0   0.995362   1.268388   0.0
# stroke_severity                       5822.0   9.194950   6.339988   0.0
# nihss_complete                        5822.0   0.969426   0.172174   0.0
# nihss_arrival_loc                     5822.0   0.181209   0.495266   0.0
# nihss_arrival_loc_questions           5822.0   0.692546   0.902159  -1.0
# nihss_arrival_loc_commands            5822.0   0.336311   0.684014  -1.0
# nihss_arrival_best_gaze               5822.0   0.270526   0.597038  -1.0
# nihss_arrival_visual                  5822.0   0.478358   0.833376  -1.0
# nihss_arrival_facial_palsy            5822.0   0.891103   0.837097  -1.0
# nihss_arrival_motor_arm_left          5822.0   0.841120   1.295403  -1.0
# nihss_arrival_motor_arm_right         5822.0   0.798179   1.269538  -1.0
# nihss_arrival_motor_leg_left          5822.0   0.869976   1.265927  -1.0
# nihss_arrival_motor_leg_right         5822.0   0.821367   1.263051  -1.0
# nihss_arrival_limb_ataxia             5822.0   0.342150   0.659845  -1.0
# nihss_arrival_sensory                 5822.0   0.535898   0.735858  -1.0
# nihss_arrival_best_language           5822.0   0.791309   1.034821  -1.0
# nihss_arrival_dysarthria              5822.0   0.774820   0.750169  -1.0
# nihss_arrival_extinction_inattention  5822.0   0.457918   0.742504  -1.0
# death                                 5822.0   0.000000   0.000000   0.0
# discharge_disability                  5822.0   2.584851   1.456675   0.0
# disability_6_month                    5822.0   2.774648   1.914077   0.0
#
#                                        25%   50%   75%   max
# age                                   67.5  77.5  82.5  92.5
# male                                   0.0   1.0   1.0   1.0
# infarction                             1.0   1.0   1.0   1.0
# thrombolysis                           0.0   0.0   0.0   0.0
# congestive_heart_failure               0.0   0.0   0.0   1.0
# hypertension                           0.0   1.0   1.0   1.0
# atrial_fibrillation                    0.0   0.0   0.0   1.0
# diabetes                               0.0   0.0   0.0   1.0
# prior_stroke_tia                       0.0   0.0   1.0   1.0
# afib_anticoagulant                     0.0   0.0   0.0   1.0
# prior_disability                       0.0   0.0   2.0   5.0
# stroke_severity                        5.0   7.0  13.0  42.0
# nihss_complete                         1.0   1.0   1.0   1.0
# nihss_arrival_loc                      0.0   0.0   0.0   3.0
# nihss_arrival_loc_questions            0.0   0.0   2.0   2.0
# nihss_arrival_loc_commands             0.0   0.0   0.0   2.0
# nihss_arrival_best_gaze                0.0   0.0   0.0   2.0
# nihss_arrival_visual                   0.0   0.0   1.0   3.0
# nihss_arrival_facial_palsy             0.0   1.0   1.0   3.0
# nihss_arrival_motor_arm_left           0.0   0.0   1.0   4.0
# nihss_arrival_motor_arm_right          0.0   0.0   1.0   4.0
# nihss_arrival_motor_leg_left           0.0   0.0   2.0   4.0
# nihss_arrival_motor_leg_right          0.0   0.0   1.0   4.0
# nihss_arrival_limb_ataxia              0.0   0.0   1.0   2.0
# nihss_arrival_sensory                  0.0   0.0   1.0   2.0
# nihss_arrival_best_language            0.0   0.0   2.0   3.0
# nihss_arrival_dysarthria               0.0   1.0   1.0   2.0
# nihss_arrival_extinction_inattention   0.0   0.0   1.0   2.0
# death                                  0.0   0.0   0.0   0.0
# discharge_disability                   1.0   3.0   4.0   5.0
# disability_6_month                     1.0   3.0   4.0   6.0

# %%
data_thrombolysis.describe().T
# Out:
#                                        count       mean        std   min  \
# age                                   5822.0  72.390072  12.839980  37.5
# male                                  5822.0   0.566644   0.495581   0.0
# infarction                            5822.0   1.000000   0.000000   1.0
# thrombolysis                          5822.0   1.000000   0.000000   1.0
# congestive_heart_failure              5822.0   0.041223   0.198823   0.0
# hypertension                          5822.0   0.514600   0.499830   0.0
# atrial_fibrillation                   5822.0   0.106321   0.308274   0.0
# diabetes                              5822.0   0.170045   0.375704   0.0
# prior_stroke_tia                      5822.0   0.203710   0.402790   0.0
# afib_anticoagulant                    5822.0   0.027482   0.163497   0.0
# prior_disability                      5822.0   0.617142   1.072337   0.0
# stroke_severity                       5822.0  10.150464   6.409844   0.0
# nihss_complete                        5822.0   0.975438   0.154799   0.0
# nihss_arrival_loc                     5822.0   0.136379   0.398355   0.0
# nihss_arrival_loc_questions           5822.0   0.703710   0.907309  -1.0
# nihss_arrival_loc_commands            5822.0   0.317245   0.662004  -1.0
# nihss_arrival_best_gaze               5822.0   0.356922   0.654339  -1.0
# nihss_arrival_visual                  5822.0   0.550326   0.863742  -1.0
# nihss_arrival_facial_palsy            5822.0   1.127276   0.881259  -1.0
# nihss_arrival_motor_arm_left          5822.0   0.893507   1.358702  -1.0
# nihss_arrival_motor_arm_right         5822.0   0.901752   1.387096  -1.0
# nihss_arrival_motor_leg_left          5822.0   0.875988   1.302441  -1.0
# nihss_arrival_motor_leg_right         5822.0   0.879079   1.344779  -1.0
# nihss_arrival_limb_ataxia             5822.0   0.310546   0.636265  -1.0
# nihss_arrival_sensory                 5822.0   0.602027   0.757134  -1.0
# nihss_arrival_best_language           5822.0   0.969942   1.085563  -1.0
# nihss_arrival_dysarthria              5822.0   0.883889   0.740688  -1.0
# nihss_arrival_extinction_inattention  5822.0   0.574030   0.787681  -1.0
# death                                 5822.0   0.000000   0.000000   0.0
# discharge_disability                  5822.0   2.047406   1.424918   0.0
# disability_6_month                    5822.0   2.043799   1.750148   0.0
#
#                                        25%   50%   75%   max
# age                                   62.5  72.5  82.5  92.5
# male                                   0.0   1.0   1.0   1.0
# infarction                             1.0   1.0   1.0   1.0
# thrombolysis                           1.0   1.0   1.0   1.0
# congestive_heart_failure               0.0   0.0   0.0   1.0
# hypertension                           0.0   1.0   1.0   1.0
# atrial_fibrillation                    0.0   0.0   0.0   1.0
# diabetes                               0.0   0.0   0.0   1.0
# prior_stroke_tia                       0.0   0.0   0.0   1.0
# afib_anticoagulant                     0.0   0.0   0.0   1.0
# prior_disability                       0.0   0.0   1.0   5.0
# stroke_severity                        5.0   8.0  14.0  38.0
# nihss_complete                         1.0   1.0   1.0   1.0
# nihss_arrival_loc                      0.0   0.0   0.0   3.0
# nihss_arrival_loc_questions            0.0   0.0   2.0   2.0
# nihss_arrival_loc_commands             0.0   0.0   0.0   2.0
# nihss_arrival_best_gaze                0.0   0.0   1.0   2.0
# nihss_arrival_visual                   0.0   0.0   1.0   3.0
# nihss_arrival_facial_palsy             0.0   1.0   2.0   3.0
# nihss_arrival_motor_arm_left           0.0   0.0   1.0   4.0
# nihss_arrival_motor_arm_right          0.0   0.0   1.0   4.0
# nihss_arrival_motor_leg_left           0.0   0.0   2.0   4.0
# nihss_arrival_motor_leg_right          0.0   0.0   2.0   4.0
# nihss_arrival_limb_ataxia              0.0   0.0   0.0   2.0
# nihss_arrival_sensory                  0.0   0.0   1.0   2.0
# nihss_arrival_best_language            0.0   1.0   2.0   3.0
# nihss_arrival_dysarthria               0.0   1.0   1.0   2.0
# nihss_arrival_extinction_inattention   0.0   0.0   1.0   2.0
# death                                  0.0   0.0   0.0   0.0
# discharge_disability                   1.0   2.0   3.0   5.0
# disability_6_month                     1.0   2.0   3.0   6.0

# %% [markdown]
# ## Save data

# %%
sampled_data = pd.concat([data_thrombolysis, sampled_no_thrombolysis])
sampled_data = sampled_data.sample(frac=1, random_state=42)    
sampled_data.to_csv('../output/nearest_neighbour_sampled_data.csv', index=False)

# %% [markdown]
# ## Test model

# %% [markdown]
# Good outcome (mRS 0-2)

# %%
cols_for_X = [
    'age',
    'male',
    'infarction',
    'thrombolysis',
    'congestive_heart_failure',
    'hypertension',
    'atrial_fibrillation',
    'diabetes',
    'prior_stroke_tia',
    'afib_anticoagulant',
    'prior_disability',
    'stroke_severity'
    ]

X = sampled_data[cols_for_X]
y = sampled_data['discharge_disability'] <= 2

# Build logistic regression model
logreg = linear_model.LogisticRegression(random_state=42)
logreg.fit(X, y)

# Get the coefficients
model_coefficients = pd.Series(logreg.coef_[0], index=X.columns)
model_coefficients
# Out:
# age                        -0.022933
# male                        0.052471
# infarction                  1.527013
# thrombolysis                0.763280
# congestive_heart_failure    0.189702
# hypertension                0.037355
# atrial_fibrillation        -0.054698
# diabetes                   -0.052366
# prior_stroke_tia            0.126180
# afib_anticoagulant          0.244685
# prior_disability           -0.634119
# stroke_severity            -0.121995
# dtype: float64

# %%
thrombolysis_odds = np.exp(model_coefficients['thrombolysis'])
print (f'Thrombolysis odds ratio {thrombolysis_odds:.2f}')
# Out:
# Thrombolysis odds ratio 2.15

# %% [markdown]
# Bad outcome (mRS 5-6)

# %%
y = sampled_data['discharge_disability'] >= 5

# Build logistic regression model
logreg = linear_model.LogisticRegression(random_state=42)
logreg.fit(X, y)

# Get the coefficients
model_coefficients = pd.Series(logreg.coef_[0], index=X.columns)
model_coefficients
# Out:
# age                         0.043692
# male                        0.059291
# infarction                 -3.777237
# thrombolysis               -0.656666
# congestive_heart_failure   -0.183524
# hypertension               -0.176702
# atrial_fibrillation         0.161942
# diabetes                   -0.081930
# prior_stroke_tia           -0.191174
# afib_anticoagulant         -0.544605
# prior_disability            0.477900
# stroke_severity             0.135582
# dtype: float64

# %%
thrombolysis_odds = np.exp(model_coefficients['thrombolysis'])
print (f'Thrombolysis odds ratio {thrombolysis_odds:.2f}')
# Out:
# Thrombolysis odds ratio 0.52
